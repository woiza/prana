# %% [markdown]
# # Exercises using geopandas
# Now it is your turn to produce some nice maps using *geopandas*. This week will again use the plant data which was part of last weeks exercises. As you might have noticed it already contains the position of the plants as *latitude* and *longitude*.

# %% [markdown]
# ## Preparation
# Load the relevant libraries and the csv file into pandas that it becomes a regular dataframe.

# %%
# load different environment before starting jupyter:
# conda env list
# conda activate geo_env

# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import pysal as ps
from pysal.contrib.viz import mapping as maps
import palettable as pltt
import seaborn as sns

df = pd.read_csv('conventional_power_plants_DE.csv', index_col=0)
# Out:
# /opt/anaconda3/envs/geo_env/lib/python3.7/site-packages/pysal/__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysalnext` package. The API changes and a guide on how to change imports is provided at https://migrating.pysal.org
#   ), VisibleDeprecationWarning)
# /opt/anaconda3/envs/geo_env/lib/python3.7/site-packages/pysal/contrib/viz/mapping.py:32: UserWarning: Bokeh not installed. Functionality related to it will not work
#   warn('Bokeh not installed. Functionality '

# %% [markdown]
# ## Exercise 1
# Create a "map" of the power plants using their position and color them by their technology.
#
# Hints:
# * May be a scatterplot would do as a first visualization.

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                           name_bnetza          block_bnetza  name_uba  \
# id
# BNA0012a  Werkskraftwerk Sappi Alfeld             Turbine 5       NaN
# BNA0021                HKW Altenstadt                   NaN       NaN
# BNA0027        Zellstoff Stendal GmbH                     -  Arneburg
# BNA1337b         Blockheizkraftwerk 1  Blockheizkraftwerk 1       NaN
# BNA1337c         Blockheizkraftwerk 2  Blockheizkraftwerk 2       NaN
#
#                                          company               street  \
# id
# BNA0012a                       Sappi Alfeld GmbH       Mühlenmarsch 1
# BNA0021   Heizkraftwerk Altenstadt GmbH & Co. KG       Triebstraße 90
# BNA0027                   Zellstoff Stendal GmbH  Goldbecker Straße 1
# BNA1337b         DS Smith Paper Deutschland GmbH       Weichertstr. 7
# BNA1337c         DS Smith Paper Deutschland GmbH       Weichertstr. 7
#
#          postcode           city           state country_code  \
# id
# BNA0012a    31061         Alfeld   Niedersachsen           DE
# BNA0021     86972     Altenstadt          Bayern           DE
# BNA0027     39596       Arneburg  Sachsen-Anhalt           DE
# BNA1337b    63741  Aschaffenburg          Bayern           DE
# BNA1337c    63741  Aschaffenburg          Bayern           DE
#
#           capacity_net_bnetza  capacity_gross_uba                fuel  \
# id
# BNA0012a                 16.0                 NaN  Biomass and biogas
# BNA0021                   9.8                 NaN  Biomass and biogas
# BNA0027                 138.9               147.0  Biomass and biogas
# BNA1337b                  1.1                 NaN  Biomass and biogas
# BNA1337c                  0.8                 NaN  Biomass and biogas
#
#              technology  chp chp_capacity_uba  commissioned  \
# id
# BNA0012a  Steam turbine  yes              NaN        1988.0
# BNA0021   Steam turbine   no              NaN        1999.0
# BNA0027   Steam turbine  yes              600        2004.0
# BNA1337b  Steam turbine  yes              NaN        2005.0
# BNA1337c  Steam turbine  yes              NaN        2010.0
#
#          commissioned_original  retrofit  shutdown     status type        lat  \
# id
# BNA0012a                  1988       NaN       NaN  operating  NaN  51.984761
# BNA0021                   1999       NaN       NaN  operating  NaN  47.797140
# BNA0027                   2004       NaN       NaN  operating  CHP  52.727130
# BNA1337b                  2005       NaN       NaN  operating  NaN  49.988218
# BNA1337c                  2010       NaN       NaN  operating  NaN  49.988218
#
#                 lon eic_code_plant eic_code_block  efficiency_data  \
# id
# BNA0012a   9.822831            NaN            NaN              NaN
# BNA0021   10.858740            NaN            NaN              NaN
# BNA0027   12.011150            NaN            NaN              NaN
# BNA1337b   9.155761            NaN            NaN              NaN
# BNA1337c   9.155761            NaN            NaN              NaN
#
#          efficiency_source  efficiency_estimate energy_source_level_1  \
# id
# BNA0012a               NaN                 0.38      Renewable energy
# BNA0021                NaN                 0.38      Renewable energy
# BNA0027                NaN                 0.38      Renewable energy
# BNA1337b               NaN                 0.38      Renewable energy
# BNA1337c               NaN                 0.38      Renewable energy
#
#          energy_source_level_2 energy_source_level_3  eeg  \
# id
# BNA0012a             Bioenergy    Biomass and biogas  yes
# BNA0021              Bioenergy    Biomass and biogas  yes
# BNA0027              Bioenergy    Biomass and biogas  yes
# BNA1337b             Bioenergy    Biomass and biogas  yes
# BNA1337c             Bioenergy    Biomass and biogas  yes
#
#                                                network_node voltage  \
# id
# BNA0012a                                                NaN       6
# BNA0021                                                 NaN      MS
# BNA0027   DE0075603959600000E00000000013559 DE0075603959...      30
# BNA1337b                                                NaN      20
# BNA1337c                                                NaN      20
#
#                                  network_operator  \
# id
# BNA0012a               Überlandwerk Leinetal GmbH
# BNA0021                      LEW Verteilnetz GmbH
# BNA0027   Infrastrukturbetrieb der Stadt Arneburg
# BNA1337b        Aschaffenburger Versorgungs GmbH
# BNA1337c        Aschaffenburger Versorgungs GmbH
#
#                                               merge_comment  comment
# id
# BNA0012a                                                NaN      NaN
# BNA0021                                                 NaN      NaN
# BNA0027   List matching type: Single UBA power plant ass...      NaN
# BNA1337b                                                NaN      NaN
# BNA1337c                                                NaN      NaN

# %%
scatterplot = sns.lmplot(x='lon', y='lat', hue='technology', fit_reg=False, data=df)

# %% [markdown]
# ## Exercise 2
# Next, use geopandas to create a Geo Data Frame containing the power plants and their coordinates. Plot a first map and compare it to the results of Exercise 2 to see whether the transformation has been successful.
#
# Hints:
# * A look at this <a href="https://geopandas.readthedocs.io/en/latest/gallery/create_geopandas_from_pandas.html"> tutorial</a> may help.

# %%
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.lon, df.lat))
print(gdf.head())
# Out:
#                           name_bnetza          block_bnetza  name_uba  \
# id
# BNA0012a  Werkskraftwerk Sappi Alfeld             Turbine 5       NaN
# BNA0021                HKW Altenstadt                   NaN       NaN
# BNA0027        Zellstoff Stendal GmbH                     -  Arneburg
# BNA1337b         Blockheizkraftwerk 1  Blockheizkraftwerk 1       NaN
# BNA1337c         Blockheizkraftwerk 2  Blockheizkraftwerk 2       NaN
#
#                                          company               street  \
# id
# BNA0012a                       Sappi Alfeld GmbH       Mühlenmarsch 1
# BNA0021   Heizkraftwerk Altenstadt GmbH & Co. KG       Triebstraße 90
# BNA0027                   Zellstoff Stendal GmbH  Goldbecker Straße 1
# BNA1337b         DS Smith Paper Deutschland GmbH       Weichertstr. 7
# BNA1337c         DS Smith Paper Deutschland GmbH       Weichertstr. 7
#
#          postcode           city           state country_code  \
# id
# BNA0012a    31061         Alfeld   Niedersachsen           DE
# BNA0021     86972     Altenstadt          Bayern           DE
# BNA0027     39596       Arneburg  Sachsen-Anhalt           DE
# BNA1337b    63741  Aschaffenburg          Bayern           DE
# BNA1337c    63741  Aschaffenburg          Bayern           DE
#
#           capacity_net_bnetza  capacity_gross_uba                fuel  \
# id
# BNA0012a                 16.0                 NaN  Biomass and biogas
# BNA0021                   9.8                 NaN  Biomass and biogas
# BNA0027                 138.9               147.0  Biomass and biogas
# BNA1337b                  1.1                 NaN  Biomass and biogas
# BNA1337c                  0.8                 NaN  Biomass and biogas
#
#              technology  chp chp_capacity_uba  commissioned  \
# id
# BNA0012a  Steam turbine  yes              NaN        1988.0
# BNA0021   Steam turbine   no              NaN        1999.0
# BNA0027   Steam turbine  yes              600        2004.0
# BNA1337b  Steam turbine  yes              NaN        2005.0
# BNA1337c  Steam turbine  yes              NaN        2010.0
#
#          commissioned_original  retrofit  shutdown     status type        lat  \
# id
# BNA0012a                  1988       NaN       NaN  operating  NaN  51.984761
# BNA0021                   1999       NaN       NaN  operating  NaN  47.797140
# BNA0027                   2004       NaN       NaN  operating  CHP  52.727130
# BNA1337b                  2005       NaN       NaN  operating  NaN  49.988218
# BNA1337c                  2010       NaN       NaN  operating  NaN  49.988218
#
#                 lon eic_code_plant eic_code_block  efficiency_data  \
# id
# BNA0012a   9.822831            NaN            NaN              NaN
# BNA0021   10.858740            NaN            NaN              NaN
# BNA0027   12.011150            NaN            NaN              NaN
# BNA1337b   9.155761            NaN            NaN              NaN
# BNA1337c   9.155761            NaN            NaN              NaN
#
#          efficiency_source  efficiency_estimate energy_source_level_1  \
# id
# BNA0012a               NaN                 0.38      Renewable energy
# BNA0021                NaN                 0.38      Renewable energy
# BNA0027                NaN                 0.38      Renewable energy
# BNA1337b               NaN                 0.38      Renewable energy
# BNA1337c               NaN                 0.38      Renewable energy
#
#          energy_source_level_2 energy_source_level_3  eeg  \
# id
# BNA0012a             Bioenergy    Biomass and biogas  yes
# BNA0021              Bioenergy    Biomass and biogas  yes
# BNA0027              Bioenergy    Biomass and biogas  yes
# BNA1337b             Bioenergy    Biomass and biogas  yes
# BNA1337c             Bioenergy    Biomass and biogas  yes
#
#                                                network_node voltage  \
# id
# BNA0012a                                                NaN       6
# BNA0021                                                 NaN      MS
# BNA0027   DE0075603959600000E00000000013559 DE0075603959...      30
# BNA1337b                                                NaN      20
# BNA1337c                                                NaN      20
#
#                                  network_operator  \
# id
# BNA0012a               Überlandwerk Leinetal GmbH
# BNA0021                      LEW Verteilnetz GmbH
# BNA0027   Infrastrukturbetrieb der Stadt Arneburg
# BNA1337b        Aschaffenburger Versorgungs GmbH
# BNA1337c        Aschaffenburger Versorgungs GmbH
#
#                                               merge_comment  comment  \
# id
# BNA0012a                                                NaN      NaN
# BNA0021                                                 NaN      NaN
# BNA0027   List matching type: Single UBA power plant ass...      NaN
# BNA1337b                                                NaN      NaN
# BNA1337c                                                NaN      NaN
#
#                            geometry
# id
# BNA0012a   POINT (9.82283 51.98476)
# BNA0021   POINT (10.85874 47.79714)
# BNA0027   POINT (12.01115 52.72713)
# BNA1337b   POINT (9.15576 49.98822)
# BNA1337c   POINT (9.15576 49.98822)

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world[world.name == 'Germany'].plot(
    color='white', edgecolor='black',figsize=(7, 10))
gdf.plot(ax=ax, color='blue')
plt.xlim([5,16])
plt.ylim([45,57])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 3
# Add the boundaries of Germany and its states using an appropriate shape file. Finally reduce the map as well as the plants to those located in Bavaria.
#
# Hint:
# * The <a href="http://www.geodatenzentrum.de/geodaten/gdz_rahmen.gdz_div?gdz_spr=deu&gdz_akt_zeile=5&gdz_anz_zeile=1&gdz_unt_zeile=15&gdz_user_id=0">The Service Centre of the Federal Government for Geo-Information and Geodesy </a> is maybe a good source for geospatial data.
#
# A:

# %%
gdf_states = gpd.read_file("DEU_shape/DEU_adm1.shp") # source: https://gadm.org/
gdf_states
# Out:
#     ID_0  ISO   NAME_0  ID_1                  NAME_1 TYPE_1 ENGTYPE_1  \
# 0     86  DEU  Germany     1       Baden-Württemberg   Land     State
# 1     86  DEU  Germany     2                  Bayern   Land     State
# 2     86  DEU  Germany     3                  Berlin   Land     State
# 3     86  DEU  Germany     4             Brandenburg   Land     State
# 4     86  DEU  Germany     5                  Bremen   Land     State
# 5     86  DEU  Germany     6                 Hamburg   Land     State
# 6     86  DEU  Germany     7                  Hessen   Land     State
# 7     86  DEU  Germany     8  Mecklenburg-Vorpommern   Land     State
# 8     86  DEU  Germany     9           Niedersachsen   Land     State
# 9     86  DEU  Germany    10     Nordrhein-Westfalen   Land     State
# 10    86  DEU  Germany    11         Rheinland-Pfalz   Land     State
# 11    86  DEU  Germany    12                Saarland   Land     State
# 12    86  DEU  Germany    13          Sachsen-Anhalt   Land     State
# 13    86  DEU  Germany    14                 Sachsen   Land     State
# 14    86  DEU  Germany    15      Schleswig-Holstein   Land     State
# 15    86  DEU  Germany    16               Thüringen   Land     State
#
#    NL_NAME_1                   VARNAME_1  \
# 0       None                        None
# 1       None                     Bavaria
# 2       None                        None
# 3       None                        None
# 4       None                        None
# 5       None                        None
# 6       None                       Hesse
# 7       None  Mecklenburg-West Pomerania
# 8       None                Lower Saxony
# 9       None      North Rhine-Westphalia
# 10      None        Rhineland-Palatinate
# 11      None                        None
# 12      None               Saxony-Anhalt
# 13      None                      Saxony
# 14      None                        None
# 15      None                   Thuringia
#
#                                              geometry
# 0   MULTIPOLYGON (((8.70837 47.71556, 8.70918 47.7...
# 1   POLYGON ((10.13386 50.55000, 10.13980 50.54252...
# 2   POLYGON ((13.17789 52.39032, 13.16575 52.39050...
# 3   POLYGON ((13.87951 53.50107, 13.87927 53.49908...
# 4   MULTIPOLYGON (((8.50506 53.23289, 8.51754 53.2...
# 5   POLYGON ((10.07162 53.71823, 10.07150 53.72192...
# 6   POLYGON ((9.49877 51.63152, 9.50474 51.62795, ...
# 7   MULTIPOLYGON (((14.26472 53.71069, 14.26472 53...
# 8   MULTIPOLYGON (((6.86528 53.59597, 6.86528 53.5...
# 9   POLYGON ((8.66628 52.52528, 8.67277 52.51795, ...
# 10  POLYGON ((7.79963 50.94302, 7.81179 50.93973, ...
# 11  POLYGON ((7.03796 49.64338, 7.05590 49.63674, ...
# 12  POLYGON ((11.63251 53.01641, 11.63239 53.00897...
# 13  POLYGON ((12.87800 51.67270, 12.87185 51.66910...
# 14  MULTIPOLYGON (((8.68972 54.06681, 8.68972 54.0...
# 15  POLYGON ((10.77189 51.64491, 10.78391 51.64098...

# %%
gdf_states.plot()

# %% [markdown]
# B (like in Bavaria):

# %%
ax2 = gdf_states.plot(
    color='white', edgecolor='black')#,figsize=(10, 9))
gdf.plot(ax=ax2, color='red')

# %%
gdf_shape_bavaria = gdf_states[gdf_states['NAME_1']=='Bayern'] # states_gdf['NAME_1']=='Bayern' returns only true/false
df_bavaria = df[df['state']=='Bayern']

gdf_bavaria_ = gpd.GeoDataFrame(df_bavaria, geometry=gpd.points_from_xy(df_bavaria['lon'], df_bavaria['lat']))

ax3 = gdf_shape_bavaria.plot(
    color='white', edgecolor='black')#,figsize=(10, 9))
gdf_bavaria_.plot(ax=ax3, color='green')

# %%
gdf_bavaria_[gdf_bavaria_.lat >= 51]
# Out:
#         name_bnetza block_bnetza name_uba                  company  \
# id
# BNA1140     Altheim      Altheim      NaN  Uniper Kraftwerke GmbH
#
#                      street postcode       city   state country_code  \
# id
# BNA1140  Kraftwerkstraße 22    84051  Essenbach  Bayern           DE
#
#          capacity_net_bnetza  capacity_gross_uba   fuel    technology chp  \
# id
# BNA1140                 17.8                 NaN  Hydro  Run-of-river  no
#
#         chp_capacity_uba  commissioned commissioned_original  retrofit  \
# id
# BNA1140              NaN        1951.0                  1951       NaN
#
#          shutdown     status type        lat        lon eic_code_plant  \
# id
# BNA1140       NaN  operating  NaN  51.536513  14.382898            NaN
#
#         eic_code_block  efficiency_data efficiency_source  \
# id
# BNA1140            NaN              NaN               NaN
#
#          efficiency_estimate energy_source_level_1 energy_source_level_2  \
# id
# BNA1140                  0.8      Renewable energy                 Hydro
#
#         energy_source_level_3 eeg          network_node voltage  \
# id
# BNA1140                   NaN  no  Schaltanlage vor Ort     110
#
#         network_operator merge_comment  comment                   geometry
# id
# BNA1140    Bayernwerk AG           NaN      NaN  POINT (14.38290 51.53651)
