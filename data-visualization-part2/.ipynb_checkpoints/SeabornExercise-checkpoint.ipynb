# %% [markdown]
# # Exercises using Seaborn
# This week's exercises will be dealing with power plant data.
# ## Preparation
# Import the relevant librarys Seaborn, matplotlib and of course pandas.

# %%
import pandas as pd
from matplotlib import pyplot as plt
# Display plots inside notebook
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Now import the file *conventional_power_plants.csv* from moodle using pandas.

# %%
df = pd.read_csv('conventional_power_plants_DE.csv')
df.dtypes
# Out:
# id                        object
# name_bnetza               object
# block_bnetza              object
# name_uba                  object
# company                   object
# street                    object
# postcode                  object
# city                      object
# state                     object
# country_code              object
# capacity_net_bnetza      float64
# capacity_gross_uba       float64
# fuel                      object
# technology                object
# chp                       object
# chp_capacity_uba          object
# commissioned             float64
# commissioned_original     object
# retrofit                 float64
# shutdown                 float64
# status                    object
# type                      object
# lat                      float64
# lon                      float64
# eic_code_plant            object
# eic_code_block            object
# efficiency_data          float64
# efficiency_source         object
# efficiency_estimate      float64
# energy_source_level_1     object
# energy_source_level_2     object
# energy_source_level_3     object
# eeg                       object
# network_node              object
# voltage                   object
# network_operator          object
# merge_comment             object
# comment                  float64
# dtype: object

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#          id                  name_bnetza          block_bnetza  name_uba  \
# 0  BNA0012a  Werkskraftwerk Sappi Alfeld             Turbine 5       NaN
# 1   BNA0021               HKW Altenstadt                   NaN       NaN
# 2   BNA0027       Zellstoff Stendal GmbH                     -  Arneburg
# 3  BNA1337b         Blockheizkraftwerk 1  Blockheizkraftwerk 1       NaN
# 4  BNA1337c         Blockheizkraftwerk 2  Blockheizkraftwerk 2       NaN
#
#                                   company               street postcode  \
# 0                       Sappi Alfeld GmbH       Mühlenmarsch 1    31061
# 1  Heizkraftwerk Altenstadt GmbH & Co. KG       Triebstraße 90    86972
# 2                  Zellstoff Stendal GmbH  Goldbecker Straße 1    39596
# 3         DS Smith Paper Deutschland GmbH       Weichertstr. 7    63741
# 4         DS Smith Paper Deutschland GmbH       Weichertstr. 7    63741
#
#             city           state country_code  capacity_net_bnetza  \
# 0         Alfeld   Niedersachsen           DE                 16.0
# 1     Altenstadt          Bayern           DE                  9.8
# 2       Arneburg  Sachsen-Anhalt           DE                138.9
# 3  Aschaffenburg          Bayern           DE                  1.1
# 4  Aschaffenburg          Bayern           DE                  0.8
#
#    capacity_gross_uba                fuel     technology  chp  \
# 0                 NaN  Biomass and biogas  Steam turbine  yes
# 1                 NaN  Biomass and biogas  Steam turbine   no
# 2               147.0  Biomass and biogas  Steam turbine  yes
# 3                 NaN  Biomass and biogas  Steam turbine  yes
# 4                 NaN  Biomass and biogas  Steam turbine  yes
#
#   chp_capacity_uba  commissioned commissioned_original  retrofit  shutdown  \
# 0              NaN        1988.0                  1988       NaN       NaN
# 1              NaN        1999.0                  1999       NaN       NaN
# 2              600        2004.0                  2004       NaN       NaN
# 3              NaN        2005.0                  2005       NaN       NaN
# 4              NaN        2010.0                  2010       NaN       NaN
#
#       status type        lat        lon eic_code_plant eic_code_block  \
# 0  operating  NaN  51.984761   9.822831            NaN            NaN
# 1  operating  NaN  47.797140  10.858740            NaN            NaN
# 2  operating  CHP  52.727130  12.011150            NaN            NaN
# 3  operating  NaN  49.988218   9.155761            NaN            NaN
# 4  operating  NaN  49.988218   9.155761            NaN            NaN
#
#    efficiency_data efficiency_source  efficiency_estimate  \
# 0              NaN               NaN                 0.38
# 1              NaN               NaN                 0.38
# 2              NaN               NaN                 0.38
# 3              NaN               NaN                 0.38
# 4              NaN               NaN                 0.38
#
#   energy_source_level_1 energy_source_level_2 energy_source_level_3  eeg  \
# 0      Renewable energy             Bioenergy    Biomass and biogas  yes
# 1      Renewable energy             Bioenergy    Biomass and biogas  yes
# 2      Renewable energy             Bioenergy    Biomass and biogas  yes
# 3      Renewable energy             Bioenergy    Biomass and biogas  yes
# 4      Renewable energy             Bioenergy    Biomass and biogas  yes
#
#                                         network_node voltage  \
# 0                                                NaN       6
# 1                                                NaN      MS
# 2  DE0075603959600000E00000000013559 DE0075603959...      30
# 3                                                NaN      20
# 4                                                NaN      20
#
#                           network_operator  \
# 0               Überlandwerk Leinetal GmbH
# 1                     LEW Verteilnetz GmbH
# 2  Infrastrukturbetrieb der Stadt Arneburg
# 3        Aschaffenburger Versorgungs GmbH
# 4        Aschaffenburger Versorgungs GmbH
#
#                                        merge_comment  comment
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2  List matching type: Single UBA power plant ass...      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN

# %% [markdown]
# ## Excercise 1: Scatterplots
#
# 1. Create a scatterplot that shows the development of the the capacity of the german power plants over the years.

# %%
sns.lmplot(x='commissioned', y='capacity_net_bnetza', fit_reg=False, data=df)
plt.ylim(0, None)
# Out:
# (0, 1480.5002161941961)

# %% [markdown]
# 2. Change the scatterplot so that it displays the points by the type of technology they use.

# %%
sns.swarmplot(x='commissioned', y='technology', data=df)

# %% [markdown]
# ## Exercise 2: Boxplots
# 1. Create a boxplot showing the distribution of the capacity by technology and ensure that the width of the diagram is at minimum 15.

# %%
plt.figure(figsize=(15, 8))
df_cap_tech = df[['technology', 'capacity_net_bnetza']].copy()
#sns.boxplot(data=df_cap_tech)
sns.boxplot(data=df_cap_tech, x="technology", y="capacity_net_bnetza")

# %% [markdown]
# 2. Change to type of plot from boxplot to swarmplot and ensure that following coloring
#     * grey = Steam turbine
#     * red = Combustion Engine
#     * yellow = Combined cycle
#     * blue = Run-of-river
#     * light-blue = Pumped storage
#     * dark blue = Reservoir
#     * orange = Gas turbine
#     * purple = Storage technologies
#
#  You may find it useful to take a look at https://www.w3schools.com/colors/colors_picker.asp as a starting point.

# %%
tech_type_colors = ['#808080',  # Steam Turbine
                    '#B80000',  # Combustion Engine
                    '#FFFF00',  # Conbined cylce
                    '#3300FF',  # Run-of-river
                    '#00CCFF',  # Pumped storage
                    '#000099',  # Reservori
                    '#FF6600',  # Gas turbine
                    '#6633CC',  # Storage technologies
                   ]

plt.figure(figsize=(15, 8))
sns.swarmplot(x='technology', y='capacity_net_bnetza', data=df, 
              palette=tech_type_colors)

# %% [markdown]
# ## Exercise 3: Barplot
# 1. Create a barchart showing the number of plants per year for 'Bayern'. This obviously requires some data munging with pandas.
#
# Hints:
# * Take look at the data frame method <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html">*loc*</a> and <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.isin.html">*isin*</a>.
# * Also, take a look at the possible chart types of <a href="https://seaborn.pydata.org/api.html">seaborn</a>.

# %%
df_bayern = df[df['state'] == 'Bayern'].groupby('commissioned').size() # returns series
df_bayern=pd.DataFrame(df_bayern) # convert series to dataframe
df_bayern['index_col'] = df_bayern.index # add index column
df_bayern.columns = ['amount', 'year']
df_bayern
# Out:
#               amount    year
# commissioned
# 1920.0             2  1920.0
# 1922.0             2  1922.0
# 1924.0             4  1924.0
# 1925.0             1  1925.0
# 1927.0             1  1927.0
# ...              ...     ...
# 2012.0             1  2012.0
# 2013.0             2  2013.0
# 2014.0             1  2014.0
# 2015.0             2  2015.0
# 2016.0             1  2016.0
#
# [66 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data=df_bayern, x='year', y='amount')
